# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./TECNOMASTERTEST.csv')
df
# Out:
#                                                nombre     precios  \
# 0              Gigabyte GeForce GTX 1660 SUPER OC 6GB      545.45
# 1              Gigabyte NVIDIA GeForce GTX 1660 Ti OC      614.99
# 2         Gigabyte GeForce RTX 3080 Ti VISION OC 12GB  1789800.00
# 3                      Gigabyte GeForce NVIDIA GT 730      108.90
# 4   Teclado Thermaltake Neptune Pro Blue Light (KB...       54.98
# 5   Intel Core i3-10105F (LGA1200, 3.7GHz, 4 Núcle...       89.05
# 6   Intel Core i3-12100F (LGA1700, 4 Cores, 8 Hilo...      124.99
# 7                           MSI GeForce 210 1GB GDDR3         NaN
# 8                MSI GeForce GTX 1650 VENTUS XS 4G OC      395.00
# 9             MSI Radeon RX 6900 XT GAMING Z TRIO 16G  1628890.00
# 10             Gigabyte GeForce GTX 1660 SUPER OC 6GB      545.45
# 11                       ARMADO DE PC N° 34 [i5-9500]      392.99
# 12                     Thermaltake Smart 500W 80 Plus         NaN
# ...

# %%
df.dropna(inplace=True)

# %%
df['precios'] = df['precios'].astype(int)

# %%
df.dtypes
# Out:
# nombre     object
# precios     int64
# stock      object
# enlaces    object
# dtype: object

# %%
df
# Out:
#                                                nombre  precios          stock  \
# 0              Gigabyte GeForce GTX 1660 SUPER OC 6GB      545  4 disponibles
# 1              Gigabyte NVIDIA GeForce GTX 1660 Ti OC      614  1 disponibles
# 2         Gigabyte GeForce RTX 3080 Ti VISION OC 12GB  1789800  2 disponibles
# 3                      Gigabyte GeForce NVIDIA GT 730      108  1 disponibles
# 4   Teclado Thermaltake Neptune Pro Blue Light (KB...       54  3 disponibles
# 5   Intel Core i3-10105F (LGA1200, 3.7GHz, 4 Núcle...       89  4 disponibles
# 6   Intel Core i3-12100F (LGA1700, 4 Cores, 8 Hilo...      124  4 disponibles
# 8                MSI GeForce GTX 1650 VENTUS XS 4G OC      395  1 disponibles
# 9             MSI Radeon RX 6900 XT GAMING Z TRIO 16G  1628890  2 disponibles
# 10             Gigabyte GeForce GTX 1660 SUPER OC 6GB      545  4 disponibles
# 11                       ARMADO DE PC N° 34 [i5-9500]      392  1 disponibles
# ...
