# %%
import pandas as pd
import numpy as np
datos = pd.read_json('./video_cards/preproceso/sp_pre.json')
datos
# Out:
#                                            nombre_sp  \
# 0  [Bracket para Tarjeta de Video BITFENIX Alchem...
#
#                                           precios_sp  \
# 0  [$14.990, $179.990, $23.990, $429.990, $599.99...
#
#                                             stock_sp  \
# 0  [\n                                CANTIDAD: +...
#
#                                             links_sp
# 0  [/products/view/76568, /products/view/80886, /...

# %%
nombre_sp = datos['nombre_sp']
#nombre_sp = nombre_sp.str.replace("\n                                ","")
#nombre_sp = nombre_sp.str.replace("                            ","")
#nombre_sp = nombre_sp.str.replace("\n",",")
nombre_sp = list(nombre_sp)
nombre_sp
# Out:
# [['Bracket para Tarjeta de Video BITFENIX Alchemy 3.0 ARGB compatible con Aura Sync',
#   'Tarjeta de video Radeon ASRock Phantom Gaming RX 550, 2GB, GDDR5, 128-Bit, PCI-e 3.0',
#   'Bracket Vertical Sharkoon PCI-E para Tarjeta de Video en Elite Shark CA200',
#   'Tarjeta de Video PNY Nvidia GeForce  GTX1650 4GB GDDR6 Dual Fan PB, 128-bit, PCI-Express 3.0 x16',
#   'Tarjeta de Video Zotac GeForce RTX 3050 Twin Edge, 8GB, GDDR6, 128Bits, PCI-e 4.0, HDMI',
#   'Tarjeta de Video MSI AMD Radeon RX 6900 XT Gaming Z Trio, 16GB GDDR6, 2425MHz 16Gbps',
#   'Tarjeta de video Zotac GeForce GTX 1650 AMP, 4GB, GDDR6, 128-Bit, HDMI',
#   'Tarjeta de Video ASUS Nvidia GeForce GT 730, 2GB GDDR5',
#   'Tarjeta de Video EVGA NVIDIA GeForce 210 1GB GDDR3 HDMI PCI-E',
#   'Tarjeta de Video Zotac GeForce GTX 1660 SUPER AMP, 6GB GDDR6',
#   'Tarjeta de Video MSI Radeon RX 6900 XT Gaming Z Trio, 16GB GDDR6, PCIe 4.0, DP x 3, HDMI x 1',
#   'Tarjeta de Video Gigabyte GeForce GTX 1660 Super OC, 6GB, PCI-e 3.0, GDDR6, 192Bit, HDMI',
#   'Bracket Vertical Sharkoon Elite PCI-E 3.0 Para tarjetas de video ',
#   'Tarjeta de Video MSI GeForce® N210-MD1G/ D3 DDR3 64 bits PCI Express x16 2.0',
#   'Tarjeta de Video Gigabyte GeForce RTX 3070Ti Gaming OC, 8GB, GDDR6X, 256Bits, PCI-e 4.0, HDMI',
#   'Tarjeta de Video Gigabyte GeForce RTX 3080Ti Vision OC, 12GB, GDDR6X, 384Bits, PCI-e 4.0, HDMI',
#   'Tarjeta de Video MSI Nvidia GeForce GT 730 2GB 128-Bit DDR3 96 CUDA Cores PCI Express 2.0',
#   'Tarjeta de Video EVGA Nvidia GeForce GT 610 1GB 64-bit DDR3 PCI-E 2.0 16x',
#   'Tarjeta de Video Zotac Nvidia GeForce GT 730 Zone Edition 2GB 64-Bit DDR3 Low Profile',
#   'Tarjeta de Video Zotac GeForce® GT 710 1GB 64-Bit DDR3 PCI Express 2.0 x 8 DirectX 12',
#   'Tarjeta de Video EVGA GeForce® GTX 1060 Gaming ACX 2.0 6GB 192-Bit GDDR5 1280 CUDA Cores',
#   'Tarjeta de Video MSI GeForce® GT 710 1GB 64-Bit DDR3 PCI Express 2.0 x16 Low Profile',
#   'Tarjeta de Video ZOTAC GeForce GTX 1060 Mini 3GB 192-bit GDDR5 Super Compact',
#   'Tarjeta Video NVidia Quadro NVS810 4GB, 8 mini-DisplayPort',
#   'Tarjeta de Video EVGA GeForce® GTX 1060 SC GAMING, ACX 2.0 3GB 192-Bit GDDR5 1152 CUDA Cores',
#   'Tarjeta de Video MSI GeForce GTX 1050 Ti 4GT OC 4GB 128-Bit GDDR5',
#   'Tarjeta de Video MSI GeForce® GTX 1050 2GT OC 2GB 128-Bit GDDR5, HDMI, DVI-D',
#   'Tarjeta de Video ZOTAC GeForce GTX 1050 2GB GDDR5 128 Bit Cuda Cores 640',
#   'Tarjeta de Video ZOTAC GeForce GTX 1050 Ti Mini, 4GB GDDR5, Super Compact, 768 CUDA cores',
#   'Tarjeta de Video MSI Nvidia GeForce® GT 730 2GB 128-Bit DDR3 96 CUDA Cores PCI Express 2.0',
#   'Tarjeta de Video EVGA GeForce GTX 1050 Ti SC GAMING, 4GB 128-Bit GDDR5, 768 CUDA Cores',
#   'Tarjeta de Video EVGA GeForce GTX 1050 Ti GAMING, 4GB 128-Bit GDDR5, 768 CUDA Cores',
#   'Tarjeta de Video EVGA GeForce® GTX 1050 SC GAMING, 2GB 128-Bit GDDR5 640 CUDA Cores',
#   'Tarjeta de Video GIGABYTE GeForce GTX 1050 Ti OC 4G 4GB 128-Bit GDDR5',
#   'Tarjeta de Video GIGABYTE GeForce GTX 1050 Ti D5 4G 4GB 128-Bit GDDR5',
#   'Tarjeta de Video GIGABYTE GeForce GTX 1050 OC 2G 2GB 128-Bit GDDR5',
#   'Tarjeta de Video MSI Radeon RX 460 2G OC 2GB 128-Bit GDDR5 PCI Express 3.0 x16',
#   'Tarjeta de Video EVGA GeForce GTX 1050 GAMING, 2GB 128-Bit GDDR5, 640 CUDA Cores',
#   'Tarjeta de Video EVGA GeForce GTX 1060 3GB SSC GAMING ACX 3.0, 3GB GDDR5, LED',
#   'Tarjeta de Video ASUS GeForce GTX 1050 2GB PHOENIX Fan Edition, 2GB 128-Bit GDDR5, 640 CUDA Cores',
#   'Tarjeta de Video EVGA GeForce GTX 1070 SC GAMING ACX 3.0 BLACK EDITION, 8GB GDDR5, LED',
#   'Tarjeta de Video EVGA GeForce GTX 1080 FTW2 DT GAMING, 8GB GDDR5X, iCX-9 Thermal Sensors & RGB LED',
#   'Tarjeta de Video ASUS GeForce® GT 1030 2GB 64-Bit GDDR5 HDMI DVI PCI Express 3.0',
#   'Tarjeta de Video ZOTAC GeForce GTX 1050 2GB GDDR5 128 Bit Cuda Cores 640',
#   'Tarjeta de Video ASUS GeForce GTX 1050 Ti 4GB PHOENIX Fan Edition, 4GB 128-Bit GDDR5',
#   'Tarjeta de Video ASUS GeForce® GT 1030 CSM Passive Cooling 2GB  64-Bit GDDR5 Low-Profile PCI-E 3.0',
#   'Tarjeta de Video ZOTAC GeForce® GT 1030 2GB GDDR5 64-bit PCIe 3.0 Low Profile',
#   'Tarjeta de Video EVGA GT1030, 2GB 64-Bits GDDR5 2048Mb, DVI-D x2',
#   'Tarjeta de Video MSI GeForce GT 1030 2G LP OC 2GB 64-Bit GDDR5 PCI-E 3.0 x16 (uses x4), Low Profile',
#   'Tarjeta de Video ZOTAC GeForce RTX 2070 AMP Extreme Core 8GB GDDR6 256-bit, IceStorm 2.0',
#   'Tarjeta de Video MSI GeForce GT 710 2GD3 LP 2GB 64-Bit DDR3 PCI Express 2.0 Low Profile',
#   'Tarjeta de Video ASUS Dual GeForce RTX 2080 8GB 256-Bit GDDR6 PCI Express 3.0 ',
#   'Tarjeta de Video GeForce MSI RTX 2080 GAMING X TRIO 8GB GDRR6 256-bit',
#   'Tarjeta de Video Nvidia GeForce RTX 2080 TI GAMING X TRIO 11GB GDDR6 352-bit',
#   'CableMod® Vertical PCI-E Bracket para tarjetas de video - HDMI + DisplayPort - Negro',
#   'Tarjeta de Video MSI NVIDIA® GeForce® GT 1030 2GD4 LP OC, Low Profile',
#   'Tarjeta de Video ZOTAC GeForce RTX 2070 Mini, 8GB 256-Bit GDDR6, IceStorm 2.0, PCI Express 3.0',
#   'Tarjeta de Video MSI RTX 2070 Armor 8G OC 8GB 256-Bit GDDR6 PCI-E 3.0 TORX 2.0',
#   'Tarjeta de Video GeForce MSI RTX 2080 GAMING X TRIO 8GB GDRR6 256-bit',
#   'Tarjeta de Video MSI GeForce RTX 2080 Ventus 8G OC 8GB 256-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video ASUS ROG STRIX GeForce RTX™ 2070 Advanced 8G GDDR6 HDMI DP 1.4 USB Type-c',
#   'Tarjeta de Video ZOTAC GAMING GeForce RTX2060 AMP Edition 6GB GDDR6 192 BIT White LED lighting',
#   'Tarjeta de Video  ZOTAC GAMING GeForce RTX2060 Twin Fan 6GB GDDR6 192 BIT ',
#   'Tarjeta de Video EVGA GeForce RTX 2060 XC Black 6GB GDDR6, HDB Fan',
#   'Tarjeta de Video GIGABYTE Radeon™ RX 570 Gaming 4GB, WINDFORCE 2X, RGB fusion',
#   'Tarjeta de Video ASUS GeForce GT 710 2GB 64-Bit GDDR5 HDMI VGA DVI',
#   'Tarjeta de Video ASUS ROG STRIX GeForce RTX™ 2070 8G GDDR6 HDMI DP 1.4 USB Type-c, AURA Sync RGB',
#   'Tarjeta de Video ZOTAC GAMING GeForce GTX 1660 Ti 6GB GDDR6 192-bit, 1536 CUDA ',
#   'Tarjeta de Video EVGA GeForce RTX 2080 Ti Black Edition 11GB 352-Bit GDDR6, Dual HDB Fans & RGB LED',
#   'Tarjeta de Video ASUS Dual GeForce RTX 2070 8GB 256-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video ASUS ROG STRIX GeForce RTX 2060 6GB 192-Bit GDDR6, 1920 CUDA Cores',
#   'Tarjeta de Video ASUS Dual GeForce RTX 2060 6GB 192-Bit GDDR6, 1920 CUDA Cores',
#   'Tarjeta de Video ZOTAC GeForce GTX 1660 Ti AMP Edition 6GB GDDR6 1536 CUDA cores',
#   'Tarjeta de Video ASUS Phoenix GeForce® GTX 1660 Ti OC Edition 6GB 192-Bit GDDR6 1536 CUDA Cores',
#   'Tarjeta de Video ZOTAC GAMING GeForce GTX 1660 6GB GDDR5 192-bit, 1280 CUDA Cores',
#   'Tarjeta de Video MSI GeForce GTX 1660 VENTUS XS 6G OC 6GB 192-Bit GDDR5, 1408 CUDA Cores',
#   'Tarjeta de Video EVGA GeForce GTX 1660 XC GAMING, 6GB GDDR5, 192-Bit, HDB Fan, CUDA Cores 1408 ',
#   'Tarjeta de Video GIGABYTE Geforce RTX 2060 OC 6G, 6GB 192-Bit GDDR6, WINDFORCE 2X',
#   'Tarjeta de Video GIGABYTE GeForce GTX 1660 GAMING OC 6G, 6GB GDDR5 192-Bit , WINDFORCE 3X, RGB',
#   'Tarjeta de Video MSI GeForce RTX 2060 GAMING Z 6G 6GB 192-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video ASUS GeForce GTX 1660 Overclocked 6GB Phoenix Fan Edition HDMI DP DVI',
#   'Tarjeta de Video EVGA GeForce RTX 2060 SC Ultra GAMING, 6GB GDDR6, Dual HDB Fans',
#   'Tarjeta de Video MSI GeForce GTX 1660 GAMING X 6G 6GB 192-Bit GDDR5 PCI Express 3.0',
#   'Tarjeta de Video MSI GeForce GTX 1660 Ti VENTUS XS 6G OC 6GB 192-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video MSI GeForce GTX 1660 Ti GAMING X 6G 6GB 192-Bit GDDR6 PCI Express 3.0 x16',
#   'Tarjeta de Video MSI GeForce RTX 2060 VENTUS 6G OC 6GB 192-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video MSI GeForce GTX 1650 GAMING X 4G 4GB 128-Bit GDDR5 PCI Express 3.0',
#   'Tarjeta de video MSI GeForce GTX 1650 VENTUS XS 4G OC 4GB 128-Bit GDDR5 PCI Express 3.0 x16',
#   'Tarjeta de Video GIGABYTE GeForce GTX 1650 WINDFORCE OC 4G, 2 x WINDFORCE Fans, 4GB 128-Bit GDDR5',
#   'Tarjeta de Video GIGABYTE GeForce RTX 2060 R2 6GB 192-Bit GDDR6 PCI Express 3.0 x16 ATX ',
#   'Tarjeta de Video ASUS TUF Gaming GeForce GTX 1660 Overclocked 6GB Dual-fan Edition HDMI DP DVI',
#   'Tarjeta de Video GIGABYTE AORUS GeForce RTX 2080 XTREME 8G, 3 x Stacked WindForce, 8GB 256-Bit GDDR6',
#   'Tarjeta de Video GIGABYTE GeForce GTX 1650 OC 4G, 2 x WINDFORCE Fans, 4GB 128-Bit GDDR5',
#   'Tarjeta de Video MSI GeForce GTX 1650 GAMING X 4G 4GB 128-Bit GDDR5 PCI Express 3.0',
#   'Tarjeta de Video ASUS GeForce GTX 1650 Overclocked 4GB Dual-fan Edition HDMI DP 1.4 DVI',
#   'Tarjeta de Video EVGA GeForce GTX 1660 Ti SC Ultra Gaming, 6GB GDDR6, Dual Fan, Metal Backplate',
#   'Tarjeta de Video EVGA GeForce GTX 1660 SC Ultra Gaming, 6GB GDDR5, Dual Fan, Metal Backplate',
#   'Tarjeta de Video VGA GeForce GTX 1650 SC Ultra Gaming, 4GB GDDR5, Dual Fan, Metal Backplate',
#   'Tarjeta de Video MSI® NVIDIA GeForce RTX2060 6GB OC Ventus',
#   'Tarjeta de Video MSI GTX 1660 TI Gaming X, 6GB, GDDR6, 192Bit, PCI-E 3.0, DisplayPort, HDMI',
#   'Tarjeta de Video ZOTAC GAMING GeForce RTX 2080 Twin Fan 8GB GDDR6 256-bit, IceStorm 2.0',
#   'Tarjeta de Video ZOTAC GAMING GeForce RTX 2080 AMP Extreme 8GB GDDR6 256-bit, IceStorm 2.0',
#   'Cable Extensor Gamer 8 Pines LIAN LI Strimer 8pin Led, 8-pin(6+2) VGA',
#   'Bracket Vertical para Tarjetas de Video, LIAN LI O11D-1 PCI-E Riser Card + PCI-E Slot Back Panel',
#   'Tarjeta de Video ZOTAC GAMING GeForce RTX 2060 SUPER AMP 8GB GDDR6 256-bit 14 Gbps, IceStorm 2.0',
#   'Tarjeta de Video ZOTAC GeForce RTX 2080 SUPER AMP 8GB GDDR6 256-bit 15.5 Gbps, IceStorm 2.0',
#   'Tarjeta de Video ZOTAC GeForce RTX 2060 SUPER AMP Extreme 8GB GDDR6 256-bit 14 Gbps, IceStorm 2.0 ',
#   'Tarjeta de Video ZOTAC GeForce RTX 2070 SUPER Twin Fan 8GB GDDR6 256-bit 14 Gbps, IceStorm 2.0',
#   'Tarjeta de Video ASUS GeForce GTX 1650 4GB 128-Bit, Phoenix Fan Overclocked Edition HDMI DP DVI',
#   'Tarjeta de Video ZOTAC GAMING GeForce RTX 2060 SUPER MINI 8GB 256-bit GDDR6, 14 Gbps, IceStorm 2.0',
#   'Tarjetas de video EVGA RTX 2080 Super Black Gaming, 8GB 256-bit GDDR6, iCX2 Cooling',
#   'Tarjeta de Video EVGA GeForce RTX 2060 Super SC Ultra Gaming, 8GB GDDR6, Dual HDB Fans',
#   'Tarjeta de Video EVGA RTX 2070 Super Black Gaming, 8GB 256-bit GDDR6, 2560 CUDA Cores',
#   'Tarjeta de Video ASUS ROG STRIX GeForce RTX 2060 SUPER 8GB 256-Bit GDDR6, PCI-E 3.0',
#   'Tarjeta de Video ASUS GeForce RTX 2060 Super 8G EVO GDDR6 Dual-Fan, HDMI, DP, DVI-D',
#   'Tarjeta de Video ASUS GeForce RTX 2070 Super Overclocked 8G EVO GDDR6 Dual-Fan Edition',
#   'Tarjeta de Video EVGA GeForce RTX 2080 Ti XC GAMING, 11GB GDDR6, Dual HDB Fans & RGB LED',
#   'Tarjeta de Video Zotac GeForce RTX 2080 Ti AMP MAXX 11GB GDDR6 352-bit, IceStorm 2.0',
#   'Tarjeta de Video Gigabyte Aorus GeForce RTX 2070 Super 8G, Windforce Stack, 8GB 256-Bit GDDR6',
#   'Tarjeta Gráfica Gigabyte RTX 2060 SUPER WINDFORCE, 8 GB GDDR6, PCIe 3.0 x 16',
#   'Tarjeta de Video Gigabyte Aorus GeForce GTX 1660 Ti 6G, 3 x WINDFORCE Fans, 6GB 192-Bit GDDR6',
#   'Tarjeta de Video ZOTAC GeForce GTX 1660 SUPER AMP 6GB GDDR6 192-bit, Super Compact',
#   'Tarjeta de Video Zotac Gaming GeForce GTX 1660 Super Twin Fan SC 6GB GDDR6 192-bit',
#   'Tarjeta de Video ZOTAC GeForce GTX 1650 SUPER, 4GB 128-Bit GDDR6 PCI Express 3.0',
#   'Vertical Graphics Card Kit para Gabinetes Elite Shark Series',
#   'Tarjeta de Video AORUS GeForce® RTX 2060 SUPER™ 8G RGB Triple Fan, WINDFORCE Stack 3X ',
#   'Tarjeta de Video EVGA GeForce RTX 2060 Super SC Black GAMING, 8GB GDDR6, Dual Fans',
#   'Tarjeta de Video Zotac Nvidia GeForce RTX 2060 6GB GDDR6 192-bit, Super Compact, IceStorm 2.0',
#   'Tarjeta de Video EVGA GeForce GTX 1660 SUPER SC Ultra Gaming, 6GB GDDR6, Dual Fan, Metal Backplate',
#   'Tarjeta de Video EVGA GeForce GTX 1650 SUPER SC Ultra Gaming, 4GB GDDR6, 1280 CUDA Cores',
#   'Tarjeta de Video EVGA GeForce RTX 2060 SC Ultra Black 6GB GDDR6 Dual Fan',
#   'Tarjeta de Video ASUS GeForce GTX 1660 Super Overclocked 6GB Dual-fan EVO, HDMI DP DVI',
#   'Tarjeta de Video ASUS ROG Strix GeForce RTX 2070 SUPER Advanced Overclocked 8G GDDR6',
#   'Tarjeta de Video MSI GeForce GTX 1660 Super Gaming X 6GB 192-Bit GDDR6 PCI Express 3.0 x16',
#   'Tarjeta de Video MSI GeForce GTX 1650 Super Gaming X 4GB 128-Bit GDDR6 PCI Express 3.0 x16',
#   'Tarjeta de Video ASUS AMD TUF Gaming X3 Radeon RX 5700 OC, 8GB 256-bit GDDR6, PCI Express x16 4.0',
#   'Tarjeta de Video MSI GeForce RTX 2080 Super Gaming X TRIO 8GB 256-Bit GDDR6, Torx Fan 3.0',
#   'Tarjeta de Video MSI GeForce GTX 1650 Super Ventus XS OC, 4GB 128-Bit GDDR6, PCI Express 3.0 x 16',
#   'Tarjeta de Video MSI GeForce RTX 2070 Super Gaming X 8GB 256-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video MSI GeForce GTX 1660 Super Ventus XS OC 6GB 192-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video MSI GeForce RTX 2060 Super Gaming X 8GB 256-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video Asus ROG Strix GeForce® RTX 2080 Super™ Advanced Edition, 8GB GDDR6 256-bit',
#   'Tarjeta de Video EVGA GeForce RTX 2070 Super XC Gaming, 8GB GDDR6, Dual HDB Fans, RGB Led',
#   'Tarjeta de Video ASUS TUF Gaming GeForce GTX 1650 SUPER Overclocked 4GB Edition HDMI DP DVI',
#   'Tarjeta de Video MSI GeForce RTX 2070 Super Ventus OC 8GB 256-Bit GDDR6 PCI Express 3.0 x16',
#   'Tarjeta de Video MSI GeForce RTX 2060 Super Ventus GP OC 8GB 256-Bit GDDR6 PCI Express 3.0 x16',
#   'Tarjeta de Video EVGA GeForce RTX 2070 SUPER FTW3 Gaming, 8GB GDDR6, iCX2 Technology, RGB LED',
#   'CAJA ABIERTA/ DAÑADA Tarjeta de Video NVIDIA Quadro P1000 4GB, Soporte hasta 4 Pantallas 4K, 4xMiniDP',
#   'Tarjeta de Video MSI Radeon RX 5500 XT Mech 8G OC, 8GB GDDR6, TORX 3.0, PCI Express 4.0',
#   'Tarjeta de Video MSI GeForce RTX 2060 Super Ventus OC, 8GB GDDR6, Ventilador TORX 2.0 ',
#   'Tarjeta Video AMD Radeon™ RX 5500 XT Gigabyte OC 4G 4GB GDDR6 1xHDMI 3xDisplayPort PCI Express 4.0',
#   'Tarjeta Video AMD Radeon™ RX 5600 XT GAMING OC 6G 6GB 192-Bit PCI-E 4.0 DDR6 DisplayPort HDMI',
#   'Tarjeta de Video Gigabyte Radeon™ RX 5600 XT WINDFORCE OC 6G, 6GB 192-Bit GDDR6',
#   'Tarjeta de Video GeForce® RTX 2080 SUPER™ WINDFORCE OC 8G',
#   'Tarjeta de Video EVGA GeForce GTX 1650 Super XC Black, 4GB 128 bit GDDR6, PCIe 3.0 16x',
#   'Tarjeta de Video MSI GTX 1660 SUPER GAMING X, 6GB DDR6, PCIe 3.0x16, Dos Fans, Luces RGB',
#   'Tarjeta de Video MSI GeForce RTX 2060 Super Gaming X 8GB 256-Bit GDDR6 PCI Express 3.0 x16',
#   'Tarjeta de Video Gigabyte Radeon™ RX 5700 GAMING OC 8G, 8GB 256-Bit GDDR6, RGB Fusion 2.0, PCIe 4.0',
#   'Tarjeta de Video MSI GeForce RTX 2060 Super Ventus GP OC 8GB 256-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video MSI GeForce RTX 2080 Super Ventus XS OC 8GB 256-Bit GDDR6 PCI Express 3.0 x16',
#   'Tarjeta de Video Zotac GeForce GT730, 4GB DDR3, PCIe 2.0 x16 Perfil Bajo, DVI',
#   'Tarjeta de Video Nvidia PNY Quadro P400, 2GB, GDDR5, 64-Bit, 30W',
#   'Tarjeta de Video MSI GeForce GTX 1650 D6 GAMING X 4GB 128-Bit GDDR6 PCI Express 3.0 x16',
#   'Tarjeta de Video GeForce® GTX 1650 D6 Windforce OC 4G, 4GB 128-Bit GDDR6 PCI Express 3.0 x16 ATX',
#   'Tarjeta de Video GeForce® GTX 1650 D6 OC 4G, 4GB GDDR6 128bit, PCI-E 3.0 x 16, ATX',
#   'Tarjeta de Video Gigabyte GeForce® RTX 2080 Super™ Gaming OC Waterforce WB 8G, RGB Fusion 2.0',
#   'Tarjeta de Video Gigabyte AORUS Radeon RX 5700 XT 8G, PCIe 4.0, 8GB 256-Bit GDDR6, RGB Fusion 2.0',
#   'Tarjeta de Video Gigabyte Radeon RX 5700 XT GAMING OC 8G, PCIe 4.0, 8GB 256-Bit GDDR6, ATX, 2.0',
#   'Tarjeta de Video EVGA GeForce RTX 2080 SUPER KO GAM, 8GB GDDR6, Dual Fans',
#   'Tarjeta de Video PNY GTX 1660 Super 6GB XLR8 Gaming Overclocked Edition, PCI-Express 3.0 ×16',
#   'Tarjeta de Video EVGA GeForce RTX 2060 KO Ultra Gaming, 6GB GDDR6, Dual Fans, PCIe 3.0 16x',
#   'Tarjeta de Video ASUS Dual Radeon RX 5700 8GB 256-Bit GDDR6 PCI Express 4.0',
#   'Tarjeta de Video ASUS TUF Gaming X3 Radeon RX 5600 XT 6GB 192-Bit GDDR6 PCI Express 4.0',
#   'Tarjeta de Video ASUS ROG Strix Radeon RX 5500 XT 8GB 128-Bit GDDR6 PCI Express 4.0',
#   'Tarjeta de Video ASUS ROG STRIX AMD Radeon RX 5700 XT Overclocked 8G GDDR6 HDMI DisplayPort',
#   'Tarjeta de Video MSI GeForce GTX 1650 D6 Ventus XS OC 4GB 128-Bit GDDR6 PCI Express 3.0 x16',
#   'Tarjeta De Video MSI Radeon RX 5500 XT Mech OC, 8GB, 128-Bit GDDR6, PCI Express 4.0  ',
#   'Tarjeta de Video MSI Radeon RX 5600 XT Gaming  MX 192-bit 6GB GDDR6, 192-bit, PCI Express 4.0',
#   'Tarjeta de Video MSI Radeon RX 5500 XT Gaming X 8G, 8GB GDDR6, 128-bit, PCI Express 4.0',
#   'Tarjeta de Video MSI Radeon RX 5500 XT Mech 4G OC, FreeSync, Ventilador TORX 3.0, PCI Express 4.0',
#   'Tarjeta de Video Zotac GeForce RTX 2070 Super Mini 8GB GDDR6 256-bit, IceStorm 2.0, Super Compact',
#   'Tarjeta de Video ASUS ROG Strix GeForce RTX 2060 EVO C Edition, 6GB GDDR6',
#   'Tarjeta de Video ASUS DUAL GeForce RTX 2060 SUPER EVO V2 OC, 8GB 256-Bit GDDR6, 2176 CUDA Cores',
#   'Tarjeta de Video Gigabyte GeForce GTX 1650 4GB 128-Bit GDDR6 PCI Express 3.0 x16 Low Profile',
#   'Kit Bracket Vertical para Tarjetas de Video LIAN LI para Lancool II',
#   'Tarjeta de Video Zotac GeForce RTX 2060 Twin Fan, 6GB GDDR6 192-bit, Super Compact',
#   'Tarjeta de Video ASUS GeForce GT 710, 1GB 32-Bit GDDR5 PCI Express 2.0 HDCP Ready Low Profile',
#   'Tarjeta de Video ASUS GeForce GTX 1650 SUPER Overclocked 4GB Phoenix Fan Edition HDMI DP DVI',
#   'Tarjeta de Video Zotac GeForce GTX 1660 6GB GDDR5 192-bit, Super Compact',
#   'Tarjeta de Video MSI RTX 2070 Super Ventus GP OC 8 GB GDDR6 256 bit, PCI Express 3.0 x16',
#   'Tarjeta de Video ASUS Dual GeForceR GTX 1650 4GB GDDR5, PCI Express 3.0',
#   'Tarjeta de Video ASUS Phoenix GeForce® GTX 1660 SUPER™ OC Edition 6GB GDDR6, PCI Express 3.0',
#   'Tarjeta de Video ASUS Dual GeForce RTX™ 2070 EVO V2 OC Edition 8GB GDDR6, PCI Express 3.0',
#   'Tarjeta de Video EVGA GTX 1650 SC Ultra 4GB 128-Bit GDDR6, Dual Fan, Metal Backplate, PCIe 3.0 16x',
#   'Tarjeta de Video MSI GeForce GTX 1650 Super Gaming X 4GB 128-Bit GDDR6 PCI Express 3.0 x16',
#   'Tarjeta de Video Zotac GeForce RTX 3080 Trinity 10GB GDDR6X 320-bit, IceStorm 2.0, PCIE 4.0',
#   'Tarjeta de Video Geforce RTX 2060 Ventus XS 6G OC, 6GB GDDR6, Nvidia G-Sync y HDR, TORX Fan 2.0',
#   'Tarjeta de Video Zotac GeForce RTX 3090 Trinity 24GB GDDR6X 384-bit, IceStorm 2.0, PCIE 4.0',
#   'Tarjeta de Video PNY RTX 3090 XLR8 Gaming EPIC-X RGB, 24GB GDDR6X, 384-bit, Triple Fan Edition',
#   'Tarjeta de Video PNY GeForce RTX 3080 XLR8 10GB Gaming EPIC-X RGB Triple Fan Edition',
#   'Tarjeta de Video PNY RTX™ 3070 8GB XLR8 Gaming EPIC-X RGB™ Triple Fan Edition, 8GB 256-bit GDDR6',
#   'Tarjeta de Video PNY GeForce® GTX 1650 SUPER™ Single Fan, PCI-Express 3.0 ×16',
#   'Tarjeta de video Asus TUF GeForce GTX 1650, 4GB, GDDR6, 128-Bit, PCI-e 3.0, HDMI, DisplayPort',
#   'Kit de Soporte Vertical para GPU Cooler Master',
#   'Tarjeta de Video EVGA GeForce RTX 2060 KO Gaming 6GB 6GB GDDR6, Dual Fans, Metal Backplate',
#   'Tarjeta de Video EVGA GeForce RTX 3080 10GB XC3 Ultra IC 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal ',
#   'Tarjeta de Video EVGA GeForce RTX 3090 24GB XC3 ULTRA IC',
#   'Tarjeta de Video MSI Radeon™ RX 5700 MECH GP OC 8GB GDDR6, 256-bit, PCI Express 4.0',
#   'Tarjeta de Video Asus ROG STRIX Radeon RX 5600 XT 6GB 192-Bit GDDR6 PCI Express 4.0',
#   'Tarjeta de Video EVGA GeForce GTX 1660 XC Black Gaming, 6GB GDDR5, HDB Fan, PCI Express 3.0',
#   'Tarjeta de Video MSI GeForce GTX 1650 Super Ventus XS OC 4GB 128-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video MSI Radeon RX 5600 XT Gaming MX 6GB 192-Bit GDDR6 PCI Express 4.0',
#   'Tarjeta de Video NVIDIA GeForce GT 730 Gigabyte, 2GB GDDR5, PCI Express x8 2.0',
#   'Tarjeta de Video PNY GeForce RTX 3070 UPRISING, 8GB GDDR6, 256-Bit, PCIE 4.0, NVIDIA Ampere, 16 Gbps',
#   'Tarjeta de Video MSI GeForce RTX 3090 VENTUS 3X 24G OC 24GB GDDR6X PCI Express 4.0 HDCP Ready SLI',
#   'Tarjeta de Video MSI GeForce RTX 3080 GAMING X TRIO, 10GB 320-Bit GDDR6X PCI Express 4.0 HDCP Ready',
#   'Tarjeta de Video Zotac GeForce RTX 3070 Twin Edge OC, 8GB GDDR6, 256-bit, 14 Gbps, PCIE 4.0 ',
#   'Tarjeta de Video Zotac GeForce RTX 3070 Twin Edge, 8GB GDDR6, 256-bit, 14 Gbps, PCIE 4.0',
#   'Tarjeta de Video Zotac GeForce RTX 3080 Trinity OC 10GB GDDR6X 320-bit 19 Gbps PCIE 4.0',
#   'Tarjeta de Video PNY GeForce RTX 3060 Ti GDDR6 8GB Dual Fan XLR8 Revel Epic-X RGB, 256 bits',
#   'Tarjeta de Video ASUS ROG Strix GeForce RTX 2060 EVO C Edition, 6GB GDDR6',
#   'Tarjeta de Video ASUS TUF Gaming GeForce GTX 1650 4GB 128-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video Gigabyte GeForce GTX 1050 Ti OC Low Profile, 4GB 128-bit GDDR5, PCI Express x16 3.0',
#   'Tarjeta de video Zotac RTX 3060 Ti Twin Edge OC, 8GB, GDDR6, 256Bit, HDMI, DisplayPort',
#   'Tarjeta de video Gigabyte RTX 3060 Ti Gaming OC Pro, 8GB, GDDR6, 256bit, HDMI, DisplayPort',
#   'Tarjeta de video EVGA 3090 FTW3 Ultra Gaming, 24GB, GDDR6X, 384Bit, Tecnología iCX3, ARGB',
#   'Tarjeta de Video Gigabyte Nvidia GeForce RTX™ 3080 EAGLE OC 10G, 10GB GDDR6X 320 bit, PCI-E 4.0',
#   'Tarjeta de Video EVGA GeForce GTX 1650 KO ULTRA GD',
#   'Tarjeta de video RX 5600XT Gaming OC (Rev 2.0), 6GB, GDDR6, 192-Bit, PCI-e 4.0, HDMI, DisplayPort',
#   'Tarjeta de video Gigabyte GTX 1650  Mini ITX, OC Edition, 4GB, 128-Bit, GDDR5, HDMI, DisplayPort',
#   'Tarjeta de video Gigabyte RX 5600 XT Windforce OC, 6GB, 192-Bit, GDDR6, PCI-e 4.0',
#   'Tarjeta de video Zotac GeForce RTX 3060Ti Twin Edge, 8GB, GDDR6, 256-Bits, PCI-e 4.0',
#   'Tarjeta de video MSI RTX 3070 Ventus 2X OC, 8GB, GDDR6, 256-Bit, 220W, DisplayPort, HDMI ',
#   'Tarjeta de Video MSI GeForce GT 730, DDR3 4GB, DirectX 12, PCIe 2.0',
#   'Tarjeta de Video MSI Radeon RX 5700 XT Gaming X',
#   'Tarjeta de Video MSI RTX 3090 Gaming X Trio 24G, GDDR6, 384Bit, PCIe 4.0',
#   'Tarjeta de video EVGA 3070 XC3 Ultra, 8GB, 256-Bit, PCIe 4.0 16x, ARGB, HDMI, DisplayPort',
#   'Tarjeta de video EVGA 3060 Ti XC, 8GB, 256-Bit, PCIe 4.0 16x, HDMI, DisplayPort',
#   'Tarjeta de video EVGA 1660 Super Black Gaming, 6GB, 192-Bit, GDDR6, HDMI, DisplayPort, PCIe 3.0 16x',
#   'Tarjeta de video Asus Rog Strix RTX 3090, 24GB, GDDR6X, RGB, 384-Bit, PCIe 4.0, HDMI, DisplayPort',
#   'Tarjeta de video Asus TUF Gaming GeForce RTX 3080 OC, 10GB, GDDR6X, 320-Bit, RGB, PCIe 4.0',
#   'Tarjeta de video Asus TUF Gaming GeForce RTX 3070, 8GB, GDDR6, RGB, PCIe 4.0, 256-Bit, DisplayPort',
#   'Tarjeta de video Asus Phoenix GeForce GTX 1650 OC, 4GB, GDDR6, 128-Bit, PCIe 3.0, HDMI, DisplayPort',
#   'Tarjeta de Video Zotac GeForce GTX 1650 OC, 4GB GDDR6, 128-Bits, PCI-e 3.0, HDMI, DisplayPort, DVI-D',
#   'Tarjeta de Video EVGA GeForce RTX 3070 FTW3 ULTRA GAMING, 8GB GDDR6, Tecnología iCX3, LED ARGB',
#   'Tarjeta de Video EVGA GeForce RTX 3080 FTW3 Ultra Gaming, 10GB GDDR6X, Tecnología iCX3, Led ARGB',
#   'Tarjeta de Video MSI GeForce GTX 1650 D6 Ventus XS OC 4GB 128-Bit GDDR6 PCI Express 3.0 x16',
#   'Tarjeta de Video PNY NVIDIA GeForce GT 710, 2GB 64-bit DDR3, PCI Express 2.0 x8',
#   'Tarjeta de video EVGA RTX 3060Ti FTW3 Ultra, 8GB GDDR6, PCI-e 4.0 x16, HDMI, DisplayPort, iCX3',
#   'Tarjeta de video Zotac GeForce RTX 3060 Twin Edge OC, 12GB GDDR6, 192-Bits, DisplayPort, HDMI 2.1',
#   'Tarjeta de video Zotac GeForce RTX 3060 Twin Edge, 12GB GDDR6, 192-Bits, DisplayPort, HDMI 2.1',
#   'Tarjeta de Video ASUS Phoenix GeForce® GTX 1650 OC Edition 4GB GDDR6',
#   'Tarjeta de video Asus TUF Gaming GeForce RTX 3060 Ti, 8GB GDDR6',
#   'Tarjeta de video GeForce RTX 3060 Ti Aus ROG Strix, 8GB GDDR6, 256-Bit, PCI-e 4.0, RGB, DisplayPort',
#   'Tarjeta de video Asus KO OC Geforce RTX 3070, 8GB, GDDR6, 256-Bit, RGB, PCI-e 4.0, HDMI, DisplayPort',
#   'Tarjeta de video MSI RTX 3060 Ventus 2X OC, 12GB, GDDR6, PCI-e 4.0, 192-Bit, HDMI, DisplayPort',
#   'Tarjeta de video EVGA GeForce RTX 3060 XC Gaming, 12GB, GDDR6, PCI-e x4, Dual Fan, HDMI, DisplayPort',
#   'Tarjeta de video PNY GeForce RTX 3060 XLR8 Gaming Revel Epic-X, RGB, 12GB, GDDR6, 192-Bits, PCI-e x4',
#   'Tarjeta de video PNY GeForce RTX 3080 XLR8, Triple Fan, RGB, 10GB, GDDR6X, 320-Bits, PCI-e x4, HDMI',
#   'Tarjeta de video PNY GeForce RTX 3090 XLR8, Triple Fan, 24GB, GDDR6X, RGB, PCI-e x4, HDMI',
#   'Tarjeta de video GeForce RTX 3060 PNY XLR8, Single Fan, RGB, 12GB GDDR6, 192-Bits, PCI-e x16, HDMI',
#   'Tarjeta de Video PNY GeForce RTX 3060 12GB UPRISING Dual Fan,PCI-Express 4.0 ×16',
#   'Tarjeta de video MSI AMD Radeon RX 6700 XT Gaming X, 12GB, GDDR6, RGB, 192-Bits, PCI-e 4.0, HDMI',
#   'Tarjeta de video MSI GeForce RTX 3070 Gaming X Trio, 8GB GDDR6, PCI-e 4.0, 256-bit, RGB, HDMI',
#   'Tarjeta de video MSI AMD Radeon RX 6700 XT Mech X2 OC, 12GB, GDDR6, 192-Bit, PCI-e 4.0, DislayPort',
#   'Tarjeta de video MSI GeForce RTX 3070 Ventus X3 OC, 8GB, GDRR6, 256-Bit, PCI-e 4.0, DisplayPort',
#   'Tarjeta de video GeForce RTX 3060 Asus Rog Strix Gaming, RGB, 12GB, GDDR6, 192-Bit, HDMI',
#   'Tarjeta de video MSI GeForce GT 710, 2GB, DDR3, 64-Bits, HDMI, DVI, 19W',
#   'Tarjeta de video MSI GeForce RTX 3090 Gaming X Trio, 24GB 384-Bit GDDR6x, PCI Express 4.0',
#   'Tarjeta de Video Gigabyte AMD Radeon RX 5500 XT OC 4G (rev 2.0), 4GB 128-bit GDDR6, PCI Express 4.0',
#   'Tarjeta de video Asus TUF GeForce RTX 3060 OC, 12GB, GDDR6, 192-Bit, PCI-e 4.0, HDMI, DisplayPort',
#   'Tarjeta de Video ASUS GeForce RTX™ 3070 OC Edition, 8GB GDDR6, PCIe 4.0, GPU Tweak II',
#   'Tarjeta de video Asus TUF GeForce RTX 3070, 8GB, GDDR6, 192-Bit, PCI-e 4.0',
#   'Tarjeta de video Asus TUF GeForce RTX 3090, 24GB, GDDR6X, 384-Bit, PCI-e 4.0',
#   'Tarjeta de video Asus Rog Strix AMD Radeon RX 6700XT Gaming, 12GB, GDDR6, PCI-e 4.0, 192-Bit',
#   'Tarjeta de Video Zotac GeForce RTX 3080Ti Trinity 12GB GDDR6X,384-bit, IceStorm 2.0, PCIE 4.0',
#   'Tarjeta de video GeForce RTX 3090 Gigabyte Eagle OC, 24GB, GDDR6X, 384-Bit, PCIE 4.0',
#   'Tarjeta de video GeForce RTX 3090 Xtreme Waterforce WB, 24GB, GDDR6X, 384-Bit, PCI-e 4.0',
#   'Tarjeta de video GeForce RTX 3070 Gigabyte Vision OC, 8GB, GDDR6, 256-Bit, PCI-e 4.0',
#   'Tarjeta de video GeForce RTX 3070 Zotac Twin Edge, 8GB, GDDR6, 256-Bit, PCI-e 4.0',
#   'Tarjeta de video GeForce RTX 3090 Zotac Trinity OC, 24GB, GDDR6X, 384-Bit, PCI-e 4.0',
#   'Tarjeta de video EVGA RTX 3090 XC3 Ultra, 24GB, GDDR6X, 384-Bit, PCI-e 4.0, HDMI',
#   'Tarjeta de video ASRock AMD Radeon RX 6900 XT OC Formula, 16GB, GDDR6, 256-Bit, PCI-e 4.0',
#   'Tarjeta de video EVGA RTX 3080Ti FTW3 Ultra, 12GB, GDDR6X, 384 Bit, PCI-e 4.0 x16',
#   'Tarjeta de video EVGA RTX 3080Ti XC3 Ultra, 12GB, GDDR6X, 384-Bit, PCI-e 4.0',
#   'Tarjeta de Video ZOTAC GeForce RTX 3070 TI Trinity 8GB GDDR6X, 256-bit, PCI-E 4.0',
#   'Tarjeta de video Asus ROG Strix GeForce RTX 2060 Evo V2, 6GB, GDDR6, 192-Bit, PCI-e 3.0, HDMI',
#   'Tarjeta de Video Nvidia Asus Dual GeForce RTX 2060 DUAL-06G-EVO OC Edition, PCIe 3.0',
#   'Tarjeta de video Asus ROG Strix GeForce RTX 3070, 8GB, GDDR6, 192-Bit, PCI-e 4.0, HDMI',
#   'Tarjeta de Video ASUS ROG Strix GeForce RTX 3070Ti, PCIe 4.0, 8GB GDDR6X, Gaming Mode',
#   'Tarjeta de Video Asus TUF Gaming GeForce RTX 3080, 10GB, GDDR6X, 320-Bit, RGB, PCIe 4.0, DisplayPort',
#   'Tarjeta de video Zotac GeForce RTX 3060Ti Twin Edge LHR, 8GB, GDDR6, 256-Bits, HDMI',
#   'Tarjeta de Video Zotac Nvidia GeForce RTX 3080 Trinity LHR, 10GB 320-Bit GDDR6X, PCIe 4.0 x16',
#   'Tarjeta de video Zotac GeForce RTX 3070 Twin Edge LHR, 8GB, GDDR6, 256-Bit, HDMI',
#   'Tarjeta de Video MSI GT730 4GB DDR3 128BIT DVI/ HDMI/ VGA, PCIe 2.0 x 16',
#   'Tarjeta de Video Asus TUF GeForce RTX 3080 V2 OC LHR, 10GB, GDDR6X, 320-Bit, PCI-e 4.0',
#   'Tarjeta de Video MSI GeForce RTX™ 3060 Ti VENTUS 3X 8G OC LHR, 8GB GDDR6, PCIe Gen 4, 256bits',
#   'Tarjeta de video Zotac GeForce GTX 1650 AMP Core, 4GB, GDDR6, 128-Bit, HDMI',
#   'Tarjeta de Video Asus TUF Gaming RTX3070Ti, 8GB GDDR6X, PCIe 4.0, RGB, 3xDP y 2xHDMI',
#   'Tarjeta de Video Asus TUF Gaming GeForce RTX 3080 OC LHR V2, 10GB, GDDR6X, 320-Bit, RGB, PCIe 4.0',
#   'Tarjeta Video Asus ROG Strix GeForce RTX™ 3080 V2 10GB GDDR6X con LHR',
#   'Tarjeta de Video MSI GeForce RTX 3060 Ti VENTUS 2X OCV1 LHR de 8GB GDDR6',
#   'Tarjeta de Video MSI Ventus GeForce RTX 3080 Ti 12GB OC GDDR6X PCIe 4.0 ATX',
#   'Tarjeta de Video Asus ROG Strix RTX3090, 24GB GDDR6X, PCIe 4.0, RGB Programable',
#   'Tarjeta de Video EVGA GeForce RTX 3080 FTW3 ULTRA, 10GB GDDR6X, ARGB, Triple Fan',
#   'Tarjeta de Video EVGA GeForce RTX 3060Ti XC Gaming, 8GB GDDR6, Dual-Fan',
#   'Tarjeta de Video MSI GeForce RTX 3060 Ti Gaming X LHR, 8GB GDDR6, MSI Torx Fan 4.0',
#   'Tarjeta de Video ZOTAC GAMING GeForce RTX2060 Black Edition 6GB GDDR6 192 BIT, IceStorm 2.0 Cooling',
#   'Tarjeta de video Zotac GeForce RTX 3070 Twin Edge LHR, 8GB GDDR6, 1256-Bits, DisplayPort, HDMI 2.1',
#   'Tarjeta de vídeo ASUS TUF GTX 1650 OC Edition de 4GB GDDR6',
#   'Tarjeta de Video ASUS TUF Gaming GeForce RTX 3060 Ti V2 OC Edition 8GB GDDR6 PCI Express 4.0',
#   'Tarjeta de Video ASUS TUF Gaming GeForce RTX 3070 V2 OC Edition 8GB GDDR6 PCI Express 4.0',
#   'Tarjeta de Video Gigabyte GeForce RTX 3050 Gaming OC, 8GB, GDDR6, 128Bits, PCI-e 4.0, HDMI',
#   'Tarjeta de Video Gigabyte GeForce RTX 3080 Gaming OC, 10GB, GDDR6X, 320Bits, PCI-e 4.0, HDMI, LHR',
#   'Tarjeta de Video Gigabyte GeForce RTX 3090 Gaming OC, 24GB, 384Bits, GDDR6X, PCI-e 4.0, HDMI',
#   'Tarjeta de Video NVidia Quadro K620 2GB 128-bit, LP PCI Express 2.0 x16 BLK',
#   'Tarjeta de Video Zotac GeForce GT 710, 2GB 64-Bit DDR3, Low profile bracket, PCI-E 2.0 x8',
#   'Tarjeta de Video ZOTAC GeForce® GTX 1060 Mini 6GB 192-bit GDDR5 Super Compact VR Ready',
#   'Tarjeta de Video MSI GeForce® GT 710 1GB 64-Bit DDR3 PCI Express 2.0 x16 LP',
#   'Tarjeta de Video MSI GeForce  GTX 1050 Ti Gaming X 4G 4GB 128-Bit GDDR5 768 CUDA Cores',
#   'Tarjeta de Video ASUS GeForce GTX 1060 3GB Dual-fan OC Edition VR , 3GB 192-Bit GDDR5, 1152 CUDA',
#   'Tarjeta Video NVidia Quadro P200 5GB GDDR5 160-bit, Cuda 1024, 4xDP 1.4',
#   'Tarjeta de Video NVidia Quadro P4000, 8GB GDDR5 256-bit, Cuda 1792, 4xDP 1.4, PCI Express 3.0 x16',
#   'Tarjeta Video NVidia Quadro P2000 5GB GDDR5 160-bit Cuda 1024, 4xDP 1.4, Bulk',
#   'Tarjeta Video NVidia Quadro P1000, 4GB (LP)',
#   'Tarjeta de Video ZOTAC GeForce® GT 1030 2GB GDDR5 64-bit PCIe 3.0 Low Profile',
#   'Tarjeta Video NVidia Quadro P1000, 4GB BLK',
#   'Tarjeta Video NVidia Quadro P4000, Pascal, 8GB GDDR5 256-bit, CUDA Cores 1792',
#   'Tarjeta de Video MSI Radeon RX 550 AERO ITX 4G OC 4B 128-Bit GDDR5,512 Stream',
#   'Tarjeta de Video MSI Radeon RX 570 ARMOR MK2 8G OC 8GB 256-Bit GDDR5 PCI Express x16',
#   'Tarjeta de Video ASUS GeForce GTX 1050 Ti CERBERUS-GTX1050TI-O4G 4GB 128-Bit GDDR5 PCI-E 3.0',
#   'Tarjeta de Video EVGA GeForce GTX 1050 SC GAMING, 3GB GDDR5, ACX 2.0',
#   'Tarjeta de Video ZOTAC GAMING GeForce RTX 2080 AMP 8GB GDDR6 256-bit, Spectra Lighting',
#   'Tarjeta de Video Zotac Nvidia GeForce RTX 2080Ti AMP! 11GB GDDR6 352-Bit, Trop Fan Premium Pack',
#   'Tarjeta de Video EVGA GeForce RTX 2080 XC ULTRA GAMING, 8GB GDDR6, Dual HDB Fans & RGB LED',
#   'Tarjeta de Video EVGA GeForce RTX 2080 Ti XC ULTRA GAMING,11GB, RGB LED, Dual HDB Fans',
#   'Tarjeta de Video EVGA GeForce RTX 2080 XC GAMING, 8GB, Dual HDB Fans & RGB LED',
#   'Tarjeta de Video ZOTAC Nvidia GeForce RTX 2080 Ti Triple Fan, 11GB GDDR6 352-bit, FireStorm',
#   'Tarjeta de Video EVGA GeForce RTX 2070 XC GAMING, 8GB GDDR6, Dual HDB Fans & RGB LED',
#   'Tarjeta de Video EVGA GeForce RTX 2070 XC ULTRA GAMING, 8GB GDDR6, Dual HDB Fans & RGB LED',
#   'Tarjeta de Video ASUS GeForce GT 1030 2GB Phoenix Fan OC Edition HDMI DVI PCI Express 3.0',
#   'Tarjeta de Video MSI GeForce RTX 2080 VENTUS 8G OC 8GB 256-Bit GDDR6 PCI-E 3.0 x16',
#   'Tarjeta de Video ASUS ROG STRIX GeForce® RTX 2080 Overclocked 8G GDDR6 HDMI DP 1.4 USB Type-c',
#   'Tarjeta de video EVGA GeForce RTX 2060 XC 6GB GDDR6, 192 Bit, HDB Fan',
#   'Tarjeta de video ASUS CERBERUS GTX1050TI 4G OC Edition GDDR5 PCIe',
#   'Tarjeta de Video Gigabyte Nvidia GeForce® GTX 1660 TI  WINDFORCE OC 6G, 6GB 192-Bit GDDR6',
#   'Tarjeta de Video NVIDIA Quadro P1000 4GB, soporte para hasta 4 pantallas 4K ',
#   'Tarjeta de Video ASUS Dual GeForce RTX™ 2080 8GB 256-Bit GDDR6, 2944 CUDA Cores',
#   'Tarjeta de Video EVGA GeForce GTX 1660Ti XC GAMING, 192 Bit, 6GB GDDR6, HDB Fan',
#   'Tarjeta de Video ROG Strix GeForce RTX™ 2060 Advanced Edition 6GB 192-Bit GDDR6 1920 CUDA Cores',
#   'Tarjeta de Video EVGA GeForce GTX 1660 XC Ultra GAMING, 6GB GDDR5, 192-Bit , HDB Fan, CUDA 1408',
#   'Tarjeta de Video GIGABYTE GeForce RTX 2070 Gaming OC 8G, 8GB GDDR6 256-bit, WINDFORCE 3X, RGB Fusion',
#   'Tarjeta de Video GIGABYTE GeForce GTX 1660 Ti GAMING OC 6G, 6GB GDDR6 192-bit, WINDFORCE 3X, RGB',
#   'Tarjeta de Video ASUS Dual GeForce GTX 1660 Ti 6GB 192-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video GIGABYTE GeForce GT 1030 2GB 64-Bit GDDR5 Low Profile',
#   'Tarjeta de Video GIGABYTE GeForce RTX 2070 WINDFORCE 8G, 3 x WINDFORCE Fans, 8GB 256-Bit GDDR6',
#   'Tarjeta de Video ASUS TUF Gaming GeForce GTX 1660 Overclocked 6GB Dual-fan Edition HDMI DP DVI',
#   'Tarjeta de Video ASUS TUF Gaming GeForce GTX 1660 Ti, 6GB 192-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video ASUS ROG Strix GeForce GTX 1660 Ti, 6GB 192-Bit GDDR6',
#   'Tarjeta de Video ASUS ROG STRIX GeForce RTX 2080 Overclocked 8G GDDR6 HDMI DP 1.4 USB Type-C',
#   'Tarjeta de Video AORUS GeForce RTX 2080 XTREME 8G, 3 x Stacked WINDFORCE Fans, 8GB 256-Bit GDDR6',
#   'Tarjeta de video MSI GeForce GTX 1650 VENTUS XS 4G OC 4GB 128-Bit GDDR5 PCI Express 3.0 x16',
#   'Tarjeta de Video MSI GeForce RTX 2070 GAMING Z 8G 8GB 256-Bit GDDR6, Twin Frozr 7 Thermal Design',
#   'Tarjeta de Video ZOTAC GeForce RTX 2080 Ti Twin Fan 11GB GDDR6 352-bit, Active Fan Control',
#   'Tarjeta de Video EVGA GeForce GTX 1660 Ti XC Ultra Gaming,  6GB GDDR6, Dual HDB Fans',
#   'ASUS GT1030-2G-CSM - Tarjeta gráfica - GF GT 1030 - 2 GB GDDR5 - PCIe 3.0 perfil bajo - DVI, HD',
#   'Tarjeta de Video HP 3ME25AA Quadro P620 Graphics Card 3ME25AA',
#   'Tarjeta de Video EVGA GeForce GTX 1650 XC ULTRA, OVERCLOCKED, 60C Gaming, 4GB 128-bit GDDR5',
#   'Tarjeta Gráfica Gigabyte GF GT 710, 2GB GDDR5, PCIe 2.0 x 8',
#   'Tarjeta de Video EVGA GeForce RTX 2070 Super XC Ultra Gaming 8GB GDDR6, Dual HDB Fans, RGB LED',
#   'Tarjeta de Video Quadro P620, 2GB GDDR5, 128-bit, PCI Express 3.0 x16',
#   'Tarjeta de Video MSI GeForce RTX 2080 Super Gaming X TRIO 8GB 256-Bit GDDR6, Torx Fan 3.0',
#   'Tarjeta de Video MSI GeForce RTX 2070 Super Gaming X 8GB 256-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video Gigabyte NVIDIA GeForce GTX 1650 SUPER OC, 4GB 128-bit GDDR6, PCI Express x16 3.0',
#   'Tarjeta de Video ASUS TUF Gaming GeForce GTX 1660 SUPER Overclocked 6GB Edition HDMI DP DVI',
#   'Tarjeta de Video Gigabyte GeForce® RTX 2060 Super™ Gaming OC 3X 8G, 8GB GDDR6 256-bit, WINDFORCE 3X',
#   'Tarjeta de Video AORUS GeForce® RTX 2080 SUPER™ 8G, 8GB GDDR6 256-bit, WINDFORCE Stack 3X',
#   'Tarjeta de Video EVGA GeForce RTX 2060 SC Black Gaming, 6GB GDDR6, Dual DBB Fans, Metal Baseplate',
#   'Tarjeta de Video ASUS TUF 3-RX5700-O8G-GAMING, 8 GB GDDR6, PCI Express 4.0 x16',
#   'Tarjeta de Video Lenovo ThinkSystem NVIDIA Quadro P620 2GB PCIe Active GPU 4X67A11584',
#   'Tarjeta de Video MSI Radeon RX 5600 XT MECH OC 6GB 192-Bit GDDR6 PCI Express 4.0',
#   'Tarjeta de Video MSI GeForce RTX 2080 Super Ventus XS OC 8GB 256-Bit GDDR6 PCI Express 3.0 x16',
#   'Tarjeta de Video MSI GeForce RTX 2070 Super Ventus OC 8GB 256-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video MSI RTX 2070 Super Ventus OC, 8GB GDDR6, TORX Fan 2.0',
#   'Tarjeta de Video Gigabyte GeForce RTX 2060 PRO-6GD 2.0 6GB 192-Bit GDDR6 PCI Express 3.0 x16 ATX',
#   'MSI RX 5600 XT MECH OC - Tarjeta grÃ¡fica - Radeon RX 5600 XT - 6 GB GDDR6 - PCIe 4.0 - HDMI, 3',
#   'Tarjeta de Video ASUS GeForce GTX 1650S ROG Strix Advanced, 4GB GDDR6, PCI Express 3.0',
#   'Tarjeta de Video MSI GeForce RTX 2060 Super Gaming X, PCI Express x8, 8 GB GDDR6',
#   'Tarjeta de Video EVGA GeForce RTX 2070 Super KO Gaming, 8GB GDDR6, Dual Fans',
#   'Tarjeta de Video ASUS TUF Gaming X3 Radeon™ RX 5600 XT EVO',
#   'Tarjeta de Video ASUS ROG Strix Radeon™ RX 5500 XT',
#   'Tarjeta de Video EVGA GeForce RTX 2080 Ti XC HYBRID GAMING, 11GB GDDR6, HYBRID, Metal Backplate',
#   'Tarjeta de Video EVGA GeForce RTX 2060 KO GAMING, 6GB GDDR6, Dual Fans, Metal Backplate',
#   'Tarjeta de Video PNY / Nvidia Quadro P2200, 5GB 160-bit GDDR5X, PCI Express x16 3.0',
#   'Tarjeta de Video ASUS ROG Strix AMD Radeon RX 5700 XT Overclocked 8GB 256-Bit GDDR6, PCI E-4.0',
#   'Tarjeta de Video  ASUS Dual Radeon RX 5600 XT DUAL-RX5600XT-T6G-EVO 6GB 192-Bit GDDR6 PCI E-4.0 ',
#   'Tarjeta de Video ASRock Radeon RX 6900 Formula OC Edition, 16GB GDDR6, 3xDP, DirectX 12',
#   'Tarjeta de Video MSI NVIDIA GeForce GT 730, 2GB 64-bit GDDR3, PCI Express 2.0',
#   'Tarjeta de Video Gigabyte GV-N730D5-2GL GeForce GT 730, 2GB GDDR5, PCIe 2.0, DVI + HDMI',
#   'Tarjeta de Video ASUS ROG Strix GeForce RTX 2080 Ti, 11GB 352-Bit GDDR6 PCI Express 3.0',
#   'Tarjeta de Video ZOTAC GAMING GeForce GTX 1660 AMP 6GB GDDR5 192-bit, IceStorm 2.0 Cooling']]

# %%
nombre_sp = pd.DataFrame(nombre_sp).T
nombre_sp = nombre_sp.replace('Tarjeta de Video ','',regex=True)
nombre_sp
# Out:
#                                                      0
# 0    Bracket para BITFENIX Alchemy 3.0 ARGB compati...
# 1    Tarjeta de video Radeon ASRock Phantom Gaming ...
# 2    Bracket Vertical Sharkoon PCI-E para en Elite ...
# 3    PNY Nvidia GeForce  GTX1650 4GB GDDR6 Dual Fan...
# 4    Zotac GeForce RTX 3050 Twin Edge, 8GB, GDDR6, ...
# ..                                                 ...
# 396  ASRock Radeon RX 6900 Formula OC Edition, 16GB...
# 397  MSI NVIDIA GeForce GT 730, 2GB 64-bit GDDR3, P...
# 398  Gigabyte GV-N730D5-2GL GeForce GT 730, 2GB GDD...
# 399  ASUS ROG Strix GeForce RTX 2080 Ti, 11GB 352-B...
# 400  ZOTAC GAMING GeForce GTX 1660 AMP 6GB GDDR5 19...
#
# [401 rows x 1 columns]

# %%
precios_sp = datos['precios_sp']
precios_sp = pd.DataFrame(precios_sp[0])
precios_sp
# Out:
#               0
# 0       $14.990
# 1      $179.990
# 2       $23.990
# 3      $429.990
# 4      $599.990
# ..          ...
# 400  $2.205.290
# 401    $112.770
# 402    $114.190
# 403  $1.499.990
# 404    $299.980
#
# [405 rows x 1 columns]

# %%
stock_sp = datos['stock_sp']
stock_sp
# Out:
# 0    [\n                                CANTIDAD: +...
# Name: stock_sp, dtype: object

# %%
stock_sp = datos['stock_sp']
stock_sp = pd.DataFrame(stock_sp)
#print(type(stock_sp))
stock_sp = stock_sp['stock_sp'].tolist()
stock_sp = pd.DataFrame(stock_sp).T
stock_sp
# Out:
#                                                      0
# 0    \n                                CANTIDAD: +2...
# 1    \n                                CANTIDAD: +2...
# 2    \n                                CANTIDAD: +2...
# 3    \n                                CANTIDAD: +2...
# 4    \n                                CANTIDAD: +2...
# ..                                                 ...
# 400  \n                                AGOTADO\n   ...
# 401  \n                                AGOTADO\n   ...
# 402  \n                                AGOTADO\n   ...
# 403  \n                                AGOTADO\n   ...
# 404  \n                                AGOTADO\n   ...
#
# [405 rows x 1 columns]

# %%
stock_sp = stock_sp.replace('        CANTIDAD: +       ','',regex=True)
stock_sp = stock_sp.replace('\n                                AGOTADO\n                        ','',regex=True)
stock_sp = stock_sp.replace({'\n                                CANTIDAD: +':'' , '\n                                CANTIDAD: ':''},regex=True)
stock_sp = stock_sp.replace({'\n':'' , '\n                        ':''},regex=True)
stock_sp = stock_sp.replace('','AGOTADO',regex=True)
stock_sp = stock_sp.replace('                        ','',regex=True)
stock_sp = stock_sp.replace('                        ','',regex=True)
stock_sp
# Out:
#            0
# 0        +20
# 1        +20
# 2        +20
# 3        +20
# 4        +20
# ..       ...
# 400  AGOTADO
# 401  AGOTADO
# 402  AGOTADO
# 403  AGOTADO
# 404  AGOTADO
#
# [405 rows x 1 columns]

# %%
links_sp = datos['links_sp']
links_sp = pd.DataFrame(links_sp)
#print(type(stock_sp))
links_sp = links_sp['links_sp'].tolist()
links_sp = pd.DataFrame(links_sp).T
links_sp
# Out:
#                         0
# 0    /products/view/76568
# 1    /products/view/80886
# 2    /products/view/77081
# 3    /products/view/77576
# 4    /products/view/83537
# ..                    ...
# 400  /products/view/81228
# 401  /products/view/81453
# 402  /products/view/82805
# 403  /products/view/66494
# 404  /products/view/66960
#
# [405 rows x 1 columns]

# %%
df_final = pd.concat([nombre_sp, precios_sp, stock_sp, links_sp],axis=1)

# %%
df_final.columns = ['nombre','precios', 'stock', 'links_sp']
df_final=df_final[~df_final["stock"].str.contains("AGOTADO", na=False)]
df_final =df_final.assign(url= 'https://www.spdigital.cl')
df_final['enlaces'] = df_final['url'] + df_final['links_sp']
df_final = df_final.drop(['url'], axis=1)
df_final = df_final.drop(['links_sp'], axis=1)
df_final
# Out:
#                                                nombre     precios stock  \
# 0   Bracket para BITFENIX Alchemy 3.0 ARGB compati...     $14.990   +20
# 1   Tarjeta de video Radeon ASRock Phantom Gaming ...    $179.990   +20
# 2   Bracket Vertical Sharkoon PCI-E para en Elite ...     $23.990   +20
# 3   PNY Nvidia GeForce  GTX1650 4GB GDDR6 Dual Fan...    $429.990   +20
# 4   Zotac GeForce RTX 3050 Twin Edge, 8GB, GDDR6, ...    $599.990   +20
# 5   MSI AMD Radeon RX 6900 XT Gaming Z Trio, 16GB ...  $1.837.590   +20
# 6   Tarjeta de video Zotac GeForce GTX 1650 AMP, 4...    $379.990   +20
# 7               ASUS Nvidia GeForce GT 730, 2GB GDDR5     $90.190   +20
# 8        EVGA NVIDIA GeForce 210 1GB GDDR3 HDMI PCI-E     $29.990   +20
# 9         Zotac GeForce GTX 1660 SUPER AMP, 6GB GDDR6    $589.990   +20
# 10  MSI Radeon RX 6900 XT Gaming Z Trio, 16GB GDDR...  $2.510.290    13
# 11  Gigabyte GeForce GTX 1660 Super OC, 6GB, PCI-e...    $549.990     7
# 12  Bracket Vertical Sharkoon Elite PCI-E 3.0 Para...     $23.990     2
# 13  MSI GeForce® N210-MD1G/ D3 DDR3 64 bits PCI Ex...     $46.390     1
# 14  Gigabyte GeForce RTX 3070Ti Gaming OC, 8GB, GD...  $1.249.990     1
# 15  Gigabyte GeForce RTX 3080Ti Vision OC, 12GB, G...  $1.799.990     1
#
#                                          enlaces
# 0   https://www.spdigital.cl/products/view/76568
# 1   https://www.spdigital.cl/products/view/80886
# 2   https://www.spdigital.cl/products/view/77081
# 3   https://www.spdigital.cl/products/view/77576
# 4   https://www.spdigital.cl/products/view/83537
# 5   https://www.spdigital.cl/products/view/82691
# 6   https://www.spdigital.cl/products/view/81380
# 7   https://www.spdigital.cl/products/view/83185
# 8   https://www.spdigital.cl/products/view/44065
# 9   https://www.spdigital.cl/products/view/82570
# 10  https://www.spdigital.cl/products/view/82631
# 11  https://www.spdigital.cl/products/view/75781
# 12  https://www.spdigital.cl/products/view/80612
# 13  https://www.spdigital.cl/products/view/38673
# 14  https://www.spdigital.cl/products/view/83412
# 15  https://www.spdigital.cl/products/view/83414

# %%
df_final
# Out:
#                                                nombre     precios stock  \
# 0   Bracket para BITFENIX Alchemy 3.0 ARGB compati...     $14.990   +20
# 1   Tarjeta de video Radeon ASRock Phantom Gaming ...    $179.990   +20
# 2   Bracket Vertical Sharkoon PCI-E para en Elite ...     $23.990   +20
# 3   PNY Nvidia GeForce  GTX1650 4GB GDDR6 Dual Fan...    $429.990   +20
# 4   Zotac GeForce RTX 3050 Twin Edge, 8GB, GDDR6, ...    $599.990   +20
# 5   MSI AMD Radeon RX 6900 XT Gaming Z Trio, 16GB ...  $1.837.590   +20
# 6   Tarjeta de video Zotac GeForce GTX 1650 AMP, 4...    $379.990   +20
# 7               ASUS Nvidia GeForce GT 730, 2GB GDDR5     $90.190   +20
# 8        EVGA NVIDIA GeForce 210 1GB GDDR3 HDMI PCI-E     $29.990   +20
# 9         Zotac GeForce GTX 1660 SUPER AMP, 6GB GDDR6    $589.990   +20
# 10  MSI Radeon RX 6900 XT Gaming Z Trio, 16GB GDDR...  $2.510.290    13
# 11  Gigabyte GeForce GTX 1660 Super OC, 6GB, PCI-e...    $549.990     7
# 12  Bracket Vertical Sharkoon Elite PCI-E 3.0 Para...     $23.990     2
# 13  MSI GeForce® N210-MD1G/ D3 DDR3 64 bits PCI Ex...     $46.390     1
# 14  Gigabyte GeForce RTX 3070Ti Gaming OC, 8GB, GD...  $1.249.990     1
# 15  Gigabyte GeForce RTX 3080Ti Vision OC, 12GB, G...  $1.799.990     1
#
#                                          enlaces
# 0   https://www.spdigital.cl/products/view/76568
# 1   https://www.spdigital.cl/products/view/80886
# 2   https://www.spdigital.cl/products/view/77081
# 3   https://www.spdigital.cl/products/view/77576
# 4   https://www.spdigital.cl/products/view/83537
# 5   https://www.spdigital.cl/products/view/82691
# 6   https://www.spdigital.cl/products/view/81380
# 7   https://www.spdigital.cl/products/view/83185
# 8   https://www.spdigital.cl/products/view/44065
# 9   https://www.spdigital.cl/products/view/82570
# 10  https://www.spdigital.cl/products/view/82631
# 11  https://www.spdigital.cl/products/view/75781
# 12  https://www.spdigital.cl/products/view/80612
# 13  https://www.spdigital.cl/products/view/38673
# 14  https://www.spdigital.cl/products/view/83412
# 15  https://www.spdigital.cl/products/view/83414

# %%
df_final.to_csv('./video_cards/resultados/spfinal.csv', index=True, encoding="latin-1")
